# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("/campaign_sale.csv")

# %%
dataset.head(7)
# Out:
#    Index  Campaign Period Sales  Buy  Historical Sales Volume  \
# 0      0             238.704762    1             1.468034e+05
# 1      1             281.680000    1             4.399842e+05
# 2      2             432.857143    1             9.704657e+05
# 3      3               0.000000    0             2.301936e+05
# 4      4             308.419048    1             1.825841e+05
# 5      5               0.000000    0             1.512525e+05
# 6      6               0.000000    0             1.377761e+06
#
#    Number of Prior Year Transactions  Number of Transactions  \
# 0                                 15                      15
# 1                                 22                      22
# 2                                 19                      19
# 3                                 17                      17
# 4                                 16                      16
# 5                                  6                       6
# ...

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=12132, step=1)

# %%
cols = dataset.columns.tolist()
cols
# Out:
# ['Index',
#  'Campaign Period Sales',
#  'Buy',
#  'Historical Sales Volume',
#  'Number of Prior Year Transactions',
#  'Number of Transactions',
#  'Purchase Breadth',
#  'Customer_engagement_days',
#  'Days_since_last_transaction',
#  'Customer_engagement_length',
#  'Language_group',
#  'Repurchase Method',
#  'Last Transaction Channel',
#  'Number of Employees',
#  'Service Level',
#  'Do No Disturb',
#  'Email Available',
#  'Desk',
#  'Executive Chair',
#  'Standard Chair',
#  'Monitor',
#  'Printer',
#  'Computer',
#  'Insurance',
#  'Toner',
#  'Office Supplies']

# %%
dataset.describe()
# Out:
#               Index  Campaign Period Sales           Buy  \
# count  12132.000000           12132.000000  12132.000000
# mean    6065.500000             107.933384      0.270936
# std     3502.351067             267.200455      0.444462
# min        0.000000               0.000000      0.000000
# 25%     3032.750000               0.000000      0.000000
# 50%     6065.500000               0.000000      0.000000
# 75%     9098.250000             137.278000      1.000000
# max    12131.000000            5927.306667      1.000000
#
#        Historical Sales Volume  Number of Prior Year Transactions  \
# count             1.213200e+04                       12132.000000
# mean              5.600768e+05                          16.512117
# std               7.039575e+05                           6.034094
# min               0.000000e+00                           1.000000
# 25%               1.792572e+05                          13.000000
# ...

# %%
type(dataset['Buy'])
# Out:
# pandas.core.series.Series

# %%
dataset.shape
# Out:
# (12132, 26)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12132 entries, 0 to 12131
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Index                              12132 non-null  int64
#  1   Campaign Period Sales              12132 non-null  float64
#  2   Buy                                12132 non-null  int64
#  3   Historical Sales Volume            12132 non-null  float64
#  4   Number of Prior Year Transactions  12132 non-null  int64
#  5   Number of Transactions             12132 non-null  int64
#  6   Purchase Breadth                   12132 non-null  int64
#  7   Customer_engagement_days           12132 non-null  int64
#  8   Days_since_last_transaction        12132 non-null  int64
#  9   Customer_engagement_length         12132 non-null  object
#  10  Language_group                     12132 non-null  object
# ...

# %% [markdown]
# Maximun number of days of customer engagement

# %%
dataset["Customer_engagement_days"].max()
# Out:
# 34770

# %%
import matplotlib.pyplot as plt

# %%
No_of_trans = dataset["Number of Transactions"].tolist()
No_of_trans
# Out:
# [15,
#  22,
#  19,
#  17,
#  16,
#  6,
#  21,
#  18,
#  15,
#  17,
#  22,
#  15,
#  10,
#  23,
#  30,
#  21,
#  19,
#  15,
#  22,
#  18,
#  8,
#  11,
#  21,
#  15,
#  4,
#  15,
#  11,
#  15,
#  17,
#  3,
#  10,
#  20,
#  22,
#  14,
#  18,
#  16,
#  4,
#  1,
#  19,
#  15,
#  15,
#  21,
#  15,
#  3,
#  4,
#  15,
#  17,
#  15,
#  30,
#  18,
#  18,
#  4,
#  21,
#  14,
#  30,
#  18,
#  12,
#  21,
#  5,
#  6,
#  20,
#  18,
#  24,
#  13,
#  9,
#  17,
#  16,
#  11,
#  22,
#  22,
#  15,
#  18,
#  21,
#  17,
#  8,
#  22,
#  20,
#  19,
#  20,
#  8,
#  17,
#  19,
#  8,
#  18,
#  24,
#  5,
#  23,
#  6,
#  8,
#  20,
#  19,
#  22,
#  22,
#  12,
#  20,
#  5,
#  22,
#  24,
#  14,
#  20,
#  12,
#  20,
#  13,
#  22,
#  20,
#  13,
#  7,
#  19,
#  14,
#  9,
#  21,
#  20,
#  15,
#  17,
#  13,
#  17,
#  21,
#  17,
#  2,
#  13,
#  18,
#  8,
#  20,
#  21,
#  19,
#  22,
#  19,
#  21,
#  20,
#  48,
#  9,
#  22,
#  19,
#  18,
#  10,
#  16,
#  16,
#  23,
#  8,
#  24,
#  19,
#  19,
#  20,
#  19,
#  21,
#  16,
# ...

# %%
languages = ["Python","Java","Rust","JavaScript","PHP","Ruby","Kotlin"]
no_of_users = [120,53,99,44,66,22,37]


plt.figure(figsize=(10, 5))
 #layout='constrained')
plt.bar(languages, no_of_users, color="y") # default colour is blue, color is used to change the color
plt.title("Popularity of Programming Languages")

plt.xlabel("Programming Languages")
plt.ylabel("No. of users")

plt.show()
